# %%
from rich.pretty import pprint

sys.path.append("..") # added!
from src.composition import *

# %%
d1 = newDomain()

# %%
d1.things

pprint(GRAPH.toDict())
# Out:
# {
# │   'thing': 'things',
# │   'composition': 'compositions',
# │   'material': 'materials',
# │   'embodiement': 'embodiments',
# │   'provenance': 'provenances',
# │   'operation': 'operations',
# │   'correspondance': 'correspondances',
# │   'system': 'systems',
# │   'passivity': 'passivities',
# │   'activity': 'activities',
# │   'influence': 'influences'
# }

# %%
d2 = addThing(domain = d1, name = "House")
pprint(d2)
# Out:
# Domain(
# │   things=(Thing(name='House'),),
# │   materials=(),
# │   embodiments=(),
# │   materialisation=(),
# │   compositions=(),
# │   systems=(),
# │   provenances=(),
# │   operations=(),
# │   correspondances=(),
# │   influences=(),
# │   activities=(),
# │   passivities=()
# )

# %%
d3 = addThing(domain = d2, name = "walls")
d4 = addThing(domain = d3, name = "roof")
d5 = addThing(domain = d4, name = "foundation")
pprint(d5)
# Out:
# Domain(
# │   things=(Thing(name='House'), Thing(name='walls'), Thing(name='roof'), Thing(name='foundation')),
# │   materials=(),
# │   embodiments=(),
# │   materialisation=(),
# │   compositions=(),
# │   systems=(),
# │   provenances=(),
# │   operations=(),
# │   correspondances=(),
# │   influences=(),
# │   activities=(),
# │   passivities=()
# )

# %%
d6 = composeThing(domain = d5, of = d5.things[0], by = d5.things[1])
d7 = composeThing(domain = d6, of = d6.things[0], by = d6.things[2])
d8 = composeThing(domain = d7, of = d7.things[0], by = d7.things[3])
pprint(d8)
# Out:
# Domain(
# │   things=(Thing(name='House'), Thing(name='walls'), Thing(name='roof'), Thing(name='foundation')),
# │   materials=(),
# │   embodiments=(),
# │   materialisation=(),
# │   compositions=(
# │   │   Composition(of=Thing(name='House'), by=Thing(name='walls')),
# │   │   Composition(of=Thing(name='House'), by=Thing(name='roof')),
# │   │   Composition(of=Thing(name='House'), by=Thing(name='foundation'))
# │   ),
# │   systems=(),
# │   provenances=(),
# │   operations=(),
# │   correspondances=[],
# │   influences=(),
# │   activities=(),
# │   passivities=()
# )

# %%
d9 = addThing(domain = d8, name = "brickwork")
d10 = addThing(domain = d9, name = "plasterwork")
pprint(d10)
# Out:
# Domain(
# │   things=(
# │   │   Thing(name='House'),
# │   │   Thing(name='walls'),
# │   │   Thing(name='roof'),
# │   │   Thing(name='foundation'),
# │   │   Thing(name='brickwork'),
# │   │   Thing(name='plasterwork')
# │   ),
# │   materials=(),
# │   embodiments=(),
# │   materialisation=(),
# │   compositions=(
# │   │   Composition(of=Thing(name='House'), by=Thing(name='walls')),
# │   │   Composition(of=Thing(name='House'), by=Thing(name='roof')),
# │   │   Composition(of=Thing(name='House'), by=Thing(name='foundation'))
# │   ),
# │   systems=(),
# │   provenances=(),
# │   operations=(),
# │   correspondances=(),
# │   influences=(),
# │   activities=(),
# │   passivities=()
# )

# %%
d11 = composeThing(domain = d10, of = d10.things[1], by = d10.things[4])
d12 = composeThing(domain = d11, of = d11.things[1], by = d11.things[5])
d12
# Out:
# Domain(things=(Thing(name='House'), Thing(name='walls'), Thing(name='roof'), Thing(name='foundation'), Thing(name='brickwork'), Thing(name='plasterwork')), materials=(), embodiments=(), materialisation=(), compositions=(Composition(of=Thing(name='House'), by=Thing(name='walls')), Composition(of=Thing(name='House'), by=Thing(name='roof')), Composition(of=Thing(name='House'), by=Thing(name='foundation')), Composition(of=Thing(name='walls'), by=Thing(name='brickwork')), Composition(of=Thing(name='walls'), by=Thing(name='plasterwork'))), systems=(), provenances=(), operations=(), correspondances=[], influences=(), activities=(), passivities=())

# %%
d13 = addMaterial(domain = d12, name = "plaster")
d14 = embodyThing(domain = d13, of = d13.things[5], by = d13.materials[0])
pprint(d14)
# Out:
# Domain(
# │   things=(
# │   │   Thing(name='House'),
# │   │   Thing(name='walls'),
# │   │   Thing(name='roof'),
# │   │   Thing(name='foundation'),
# │   │   Thing(name='brickwork'),
# │   │   Thing(name='plasterwork')
# │   ),
# │   materials=(Material(name='plaster'),),
# │   embodiments=(Embodiment(of=Thing(name='plasterwork'), by=Material(name='plaster')),),
# │   materialisation=(Thing(name='plaster'),),
# │   compositions=(
# │   │   Composition(of=Thing(name='House'), by=Thing(name='walls')),
# │   │   Composition(of=Thing(name='House'), by=Thing(name='roof')),
# │   │   Composition(of=Thing(name='House'), by=Thing(name='foundation')),
# │   │   Composition(of=Thing(name='walls'), by=Thing(name='brickwork')),
# │   │   Composition(of=Thing(name='walls'), by=Thing(name='plasterwork'))
# │   ),
# │   systems=(),
# │   provenances=(),
# │   operations=(),
# │   correspondances=[],
# │   influences=(),
# │   activities=(),
# │   passivities=()
# )

# %%
d15 = addThing(domain = d14, name = "slab insulation")
d16 = addThing(domain = d15, name = "roll insulation")
d17 = addSystem(domain = d16, name = "thermal insulation")
d17
# Out:
# Domain(things=(Thing(name='House'), Thing(name='walls'), Thing(name='roof'), Thing(name='foundation'), Thing(name='brickwork'), Thing(name='plasterwork'), Thing(name='slab insulation'), Thing(name='roll insulation')), materials=(Material(name='plaster'),), embodiments=(Embodiment(of=Thing(name='plasterwork'), by=Material(name='plaster')),), materialisation=(Thing(name='plaster'),), compositions=(Composition(of=Thing(name='House'), by=Thing(name='walls')), Composition(of=Thing(name='House'), by=Thing(name='roof')), Composition(of=Thing(name='House'), by=Thing(name='foundation')), Composition(of=Thing(name='walls'), by=Thing(name='brickwork')), Composition(of=Thing(name='walls'), by=Thing(name='plasterwork'))), systems=(System(name='thermal insulation'),), provenances=(), operations=(), correspondances=(), influences=(), activities=(), passivities=())

# %%
d18 = addThing(domain = d17, name = "first floor")
d18
# Out:
# Domain(things=(Thing(name='House'), Thing(name='walls'), Thing(name='roof'), Thing(name='foundation'), Thing(name='brickwork'), Thing(name='plasterwork'), Thing(name='slab insulation'), Thing(name='roll insulation'), Thing(name='first floor')), materials=(Material(name='plaster'),), embodiments=(Embodiment(of=Thing(name='plasterwork'), by=Material(name='plaster')),), materialisation=(Thing(name='plaster'),), compositions=(Composition(of=Thing(name='House'), by=Thing(name='walls')), Composition(of=Thing(name='House'), by=Thing(name='roof')), Composition(of=Thing(name='House'), by=Thing(name='foundation')), Composition(of=Thing(name='walls'), by=Thing(name='brickwork')), Composition(of=Thing(name='walls'), by=Thing(name='plasterwork'))), systems=(System(name='thermal insulation'),), provenances=(), operations=(), correspondances=(), influences=(), activities=(), passivities=())

# %%
d19 = composeThing(domain = d18, of = d18.things[1], by = d18.things[6])
d19
# Out:
# Domain(things=(Thing(name='House'), Thing(name='walls'), Thing(name='roof'), Thing(name='foundation'), Thing(name='brickwork'), Thing(name='plasterwork'), Thing(name='slab insulation'), Thing(name='roll insulation'), Thing(name='first floor')), materials=(Material(name='plaster'),), embodiments=(Embodiment(of=Thing(name='plasterwork'), by=Material(name='plaster')),), materialisation=(Thing(name='plaster'),), compositions=(Composition(of=Thing(name='House'), by=Thing(name='walls')), Composition(of=Thing(name='House'), by=Thing(name='roof')), Composition(of=Thing(name='House'), by=Thing(name='foundation')), Composition(of=Thing(name='walls'), by=Thing(name='brickwork')), Composition(of=Thing(name='walls'), by=Thing(name='plasterwork')), Composition(of=Thing(name='walls'), by=Thing(name='slab insulation'))), systems=(System(name='thermal insulation'),), provenances=(), operations=(), correspondances=[], influences=(), activities=(), passivities=())

# %%
d20 = addPassiveInfluence(domain = d19, system = d19.systems[0], of = d19.things[1], by = d19.things[6])
pprint(d20)
# Out:
# Domain(
# │   things=(
# │   │   Thing(name='House'),
# │   │   Thing(name='walls'),
# │   │   Thing(name='roof'),
# │   │   Thing(name='foundation'),
# │   │   Thing(name='brickwork'),
# │   │   Thing(name='plasterwork'),
# │   │   Thing(name='slab insulation'),
# │   │   Thing(name='roll insulation'),
# │   │   Thing(name='first floor')
# │   ),
# │   materials=(Material(name='plaster'),),
# │   embodiments=(Embodiment(of=Thing(name='plasterwork'), by=Material(name='plaster')),),
# │   materialisation=(Thing(name='plaster'),),
# │   compositions=(
# │   │   Composition(of=Thing(name='House'), by=Thing(name='walls')),
# │   │   Composition(of=Thing(name='House'), by=Thing(name='roof')),
# │   │   Composition(of=Thing(name='House'), by=Thing(name='foundation')),
# │   │   Composition(of=Thing(name='walls'), by=Thing(name='brickwork')),
# │   │   Composition(of=Thing(name='walls'), by=Thing(name='plasterwork')),
# ...

# %%
d21 = addSystem(domain = d20, name = "heating")
d22 = addThing(domain = d21, name = "wall heaters")
d23 = addThing(domain = d22, name = "wiring loom")
d24 = addThing(domain = d23, name = "electricity")


pprint(d24)
# Out:
# Domain(
# │   things=(
# │   │   Thing(name='House'),
# │   │   Thing(name='walls'),
# │   │   Thing(name='roof'),
# │   │   Thing(name='foundation'),
# │   │   Thing(name='brickwork'),
# │   │   Thing(name='plasterwork'),
# │   │   Thing(name='slab insulation'),
# │   │   Thing(name='roll insulation'),
# │   │   Thing(name='first floor'),
# │   │   Thing(name='wall heaters'),
# │   │   Thing(name='wiring loom'),
# │   │   Thing(name='electricity')
# │   ),
# │   materials=(Material(name='plaster'),),
# │   embodiments=(Embodiment(of=Thing(name='plasterwork'), by=Material(name='plaster')),),
# │   materialisation=(Thing(name='plaster'),),
# │   compositions=(
# │   │   Composition(of=Thing(name='House'), by=Thing(name='walls')),
# │   │   Composition(of=Thing(name='House'), by=Thing(name='roof')),
# │   │   Composition(of=Thing(name='House'), by=Thing(name='foundation')),
# │   │   Composition(of=Thing(name='walls'), by=Thing(name='brickwork')),
# ...

# %%
d25 = addOperation(domain = d24, of = d24.things[9], by = d24.things[11])
d26 = addActiveInfluence(domain = d25, system = d25.systems[1], of = d25.things[9], by = d25.things[1], operations=[d25.operations[0],])
pprint(d26)
# Out:
# Domain(
# │   things=(
# │   │   Thing(name='House'),
# │   │   Thing(name='walls'),
# │   │   Thing(name='roof'),
# │   │   Thing(name='foundation'),
# │   │   Thing(name='brickwork'),
# │   │   Thing(name='plasterwork'),
# │   │   Thing(name='slab insulation'),
# │   │   Thing(name='roll insulation'),
# │   │   Thing(name='first floor'),
# │   │   Thing(name='wall heaters'),
# │   │   Thing(name='wiring loom'),
# │   │   Thing(name='electricity')
# │   ),
# │   materials=(Material(name='plaster'),),
# │   embodiments=(Embodiment(of=Thing(name='plasterwork'), by=Material(name='plaster')),),
# │   materialisation=(Thing(name='plaster'),),
# │   compositions=(
# │   │   Composition(of=Thing(name='House'), by=Thing(name='walls')),
# │   │   Composition(of=Thing(name='House'), by=Thing(name='roof')),
# │   │   Composition(of=Thing(name='House'), by=Thing(name='foundation')),
# │   │   Composition(of=Thing(name='walls'), by=Thing(name='brickwork')),
# ...

# %%
d27 = addProvenance(domain = d26, of = d26.things[11], by = d26.things[10])
pprint(d27)
# Out:
# Domain(
# │   things=(
# │   │   Thing(name='House'),
# │   │   Thing(name='walls'),
# │   │   Thing(name='roof'),
# │   │   Thing(name='foundation'),
# │   │   Thing(name='brickwork'),
# │   │   Thing(name='plasterwork'),
# │   │   Thing(name='slab insulation'),
# │   │   Thing(name='roll insulation'),
# │   │   Thing(name='first floor'),
# │   │   Thing(name='wall heaters'),
# │   │   Thing(name='wiring loom'),
# │   │   Thing(name='electricity')
# │   ),
# │   materials=(Material(name='plaster'),),
# │   embodiments=(Embodiment(of=Thing(name='plasterwork'), by=Material(name='plaster')),),
# │   materialisation=(Thing(name='plaster'),),
# │   compositions=(
# │   │   Composition(of=Thing(name='House'), by=Thing(name='walls')),
# │   │   Composition(of=Thing(name='House'), by=Thing(name='roof')),
# │   │   Composition(of=Thing(name='House'), by=Thing(name='foundation')),
# │   │   Composition(of=Thing(name='walls'), by=Thing(name='brickwork')),
# ...

# %%
d28 = addThing(domain = d27, name = "Consumer Unit")
d29 =  addPassiveInfluence(domain = d28, system = d28.systems[0], of = d28.things[12], by = d28.things[11])


pprint(d29)
# Out:
# Domain(
# │   things=(
# │   │   Thing(name='House'),
# │   │   Thing(name='walls'),
# │   │   Thing(name='roof'),
# │   │   Thing(name='foundation'),
# │   │   Thing(name='brickwork'),
# │   │   Thing(name='plasterwork'),
# │   │   Thing(name='slab insulation'),
# │   │   Thing(name='roll insulation'),
# │   │   Thing(name='first floor'),
# │   │   Thing(name='wall heaters'),
# │   │   Thing(name='wiring loom'),
# │   │   Thing(name='electricity'),
# │   │   Thing(name='Consumer Unit')
# │   ),
# │   materials=(Material(name='plaster'),),
# │   embodiments=(Embodiment(of=Thing(name='plasterwork'), by=Material(name='plaster')),),
# │   materialisation=(Thing(name='plaster'),),
# │   compositions=(
# │   │   Composition(of=Thing(name='House'), by=Thing(name='walls')),
# │   │   Composition(of=Thing(name='House'), by=Thing(name='roof')),
# │   │   Composition(of=Thing(name='House'), by=Thing(name='foundation')),
# ...

# %%
d30 = addNode(domain = d29, element = GRAPH.THING, name = "beef")
print(GRAPH.THING)
pprint(d30)
# Out:
# GRAPH.THING
# Domain(
# │   things=(
# │   │   Thing(name='House'),
# │   │   Thing(name='walls'),
# │   │   Thing(name='roof'),
# │   │   Thing(name='foundation'),
# │   │   Thing(name='brickwork'),
# │   │   Thing(name='plasterwork'),
# │   │   Thing(name='slab insulation'),
# │   │   Thing(name='roll insulation'),
# │   │   Thing(name='first floor'),
# │   │   Thing(name='wall heaters'),
# │   │   Thing(name='wiring loom'),
# │   │   Thing(name='electricity'),
# │   │   Thing(name='Consumer Unit'),
# │   │   Thing(name='beef')
# │   ),
# │   materials=(Material(name='plaster'),),
# │   embodiments=(Embodiment(of=Thing(name='plasterwork'), by=Material(name='plaster')),),
# │   materialisation=(Thing(name='plaster'),),
# │   compositions=(
# │   │   Composition(of=Thing(name='House'), by=Thing(name='walls')),
# │   │   Composition(of=Thing(name='House'), by=Thing(name='roof')),
# │   │   Composition(of=Thing(name='House'), by=Thing(name='foundation')),
# ...

# %%
import networkx as nx
import matplotlib.pyplot as plt


def decomposer(domain: Domain, relationship: RELATIONSHIPS):
    composition_list = []
    print("rel: ", relationship.plural)
    #target = domain.dict(include={relationship.plural})
    target = domain.get_element_container(relationship)
    print("Target: ", target)
    for c in target:
        print("c:", c.of)
        composition_list.append((c.of.name, c.by.name),)
    return composition_list
               
def decompose_compositions(domain: Domain):
    return decomposer(domain = domain, relationship = RELATIONSHIPS.COMPOSITION)

def decompose_operations(domain: Domain):
    return decomposer(domain = domain, relationship = RELATIONSHIPS.OPERATION)

def decompose_provenances(domain: Domain):
    return decomposer(domain = domain, relationship = RELATIONSHIPS.PROVENANCE)

def decompose_influences(domain: Domain):
    return decomposer(domain = domain, relationship = RELATIONSHIPS.INFLUENCE)

edgelist=[(0, 1), (1, 2), (2, 3), (3, 0)],

compositions = decompose_compositions(d26)

print("compositions: ", compositions)

#def decompose_influences(domain: Domain):
#    influence_list = []
#    for i in domain.influences:
#        influence_list.append([i.containing.of.name, i.containing.by.name])
#    for p in domain.provenances:
#        influence_list.append([p.of.name, p.by.name])
#
#    return influence_list
#
#influences = decompose_influences(d26)
#
#print("influences: ", influences)

def how_get(domain: Domain):
    influence_list = []
    operations = decompose_operations(domain = domain)
    provenances = decompose_provenances(domain = domain)
    influences = decompose_influences(domain = domain)
    graph_list = {"operations": operations, "provenances": provenances, "influences": influences}
    return graph_list
                                                            

how = how_get(d30)

pprint(how)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 import networkx as nx
#       2 import matplotlib.pyplot as plt
#       5 def decomposer(domain: Domain, relationship: RELATIONSHIPS):
#
# ModuleNotFoundError: No module named 'networkx'

# %%
G = nx.DiGraph(compositions)

print("G: ", G.nodes)

for layer, nodes in enumerate(nx.topological_generations(G)):
    # `multipartite_layout` expects the layer as a node attribute, so add the
    # numeric layer value as a node attribute
    for node in nodes:
        G.nodes[node]["layer"] = layer
        print(node, layer)

# Compute the multipartite_layout using the "layer" node attribute
pos = nx.multipartite_layout(G, subset_key="layer")
options = {
    "font_size": 36,
    "node_size": 3000,
    "node_color": "white",
    "edgecolors": "black",
    "linewidths": 5,
    "width": 5,
}


fig, ax = plt.subplots()
nx.draw_networkx(G, pos=pos, ax=ax)
print("nx: ", nx.__dict__['edgelist'])
nx.draw_networkx_edges(G, pos=pos, ax=ax, edge_color="red", width=2)
print("G 2", G.nodes)
print("pos: ", pos)

nx.draw_networkx_nodes(G, pos=pos, ax=ax, node_color="tab:red")
ax.set_title("DAG Composition in Topological Order")


plt.show()
# Out:
# G:  ['House', 'walls', 'roof', 'foundation', 'brickwork', 'plasterwork', 'slab insulation']
# House 0
# walls 1
# roof 1
# foundation 1
# brickwork 2
# plasterwork 2
# slab insulation 2
# nx:  <module 'networkx.readwrite.edgelist' from '/home/bramblefinch/Projects/simulation/venv/lib/python3.10/site-packages/networkx/readwrite/edgelist.py'>
# G 2 ['House', 'walls', 'roof', 'foundation', 'brickwork', 'plasterwork', 'slab insulation']
# pos:  {'House': array([-1.,  0.]), 'foundation': array([-0.22222222, -0.77777778]), 'roof': array([-0.22222222,  0.        ]), 'walls': array([-0.22222222,  0.77777778]), 'slab insulation': array([ 0.55555556, -0.77777778]), 'plasterwork': array([0.55555556, 0.        ]), 'brickwork': array([0.55555556, 0.77777778])}

# %%
def coordinate_generator(graph_dict):
    raw_list = []
    for key, value in graph_dict.items():
        for item in value:
            raw_list.append(item)
    return raw_list

print(coordinate_generator(how))


G = nx.DiGraph(coordinate_generator(how))

for layer, nodes in enumerate(nx.topological_generations(G)):
    # `multipartite_layout` expects the layer as a node attribute, so add the
    # numeric layer value as a node attribute
    for node in nodes:
        G.nodes[node]["layer"] = layer
        print(node, layer)

# Compute the multipartite_layout using the "layer" node attribute
pos = nx.multipartite_layout(G, subset_key="layer")
    
options = {
    "font_size": 36,
    "node_size": 3000,
    "node_color": "white",
    "edgecolors": "black",
    "linewidths": 5,
    "width": 5,
}


fig, ax = plt.subplots()
#nx.draw_networkx(G, pos=pos, ax=ax)
print(G.nodes)
nx.draw_networkx(G, pos=pos, ax=ax)

nx.draw_networkx_nodes(G, pos=pos, ax=ax, node_color="tab:red")

nx.draw_networkx_edges(G, pos=pos, edgelist=how['operations'], ax=ax, edge_color="tab:green", width=2)
nx.draw_networkx_edges(G, pos=pos, edgelist=how['provenances'], ax=ax, edge_color="tab:red", width=2)
nx.draw_networkx_edges(G, pos=pos, edgelist=how['influences'], ax=ax, edge_color="tab:blue", width=2)

ax.set_title("DAG System Influence in Topological Order")


plt.show()
# Out:
# [('wall heaters', 'electricity'), ('electricity', 'wiring loom'), ('walls', 'slab insulation'), ('wall heaters', 'walls'), ('Consumer Unit', 'electricity')]
# wall heaters 0
# Consumer Unit 0
# walls 1
# electricity 1
# slab insulation 2
# wiring loom 2
# ['wall heaters', 'electricity', 'wiring loom', 'walls', 'slab insulation', 'Consumer Unit']

# %%
import matplotlib.pyplot as plt
import networkx as nx

G = nx.house_graph()
# explicitly set positions
pos = {0: (0, 0), 1: (1, 0), 2: (0, 1), 3: (1, 1), 4: (0.5, 3.0)}

# Plot nodes with different properties for the "wall" and "roof" nodes
nx.draw_networkx_nodes(
    G, pos, node_size=3000, nodelist=[0, 1, 2, 3], node_color="tab:blue"
)
nx.draw_networkx_nodes(G, pos, node_size=2000, nodelist=[4], node_color="tab:orange")
nx.draw_networkx_edges(G, pos, alpha=0.5, width=6)
# Customize axes
ax = plt.gca()
ax.margins(0.11)
plt.tight_layout()
plt.axis("off")
plt.show()
